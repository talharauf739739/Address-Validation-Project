# %%
"""
Python script for batch geocoding of addresses using the Google Geocoding API.

This script allows for massive lists of addresses to be geocoded for free by pausing when the
geocoder hits the free rate limit set by Google (2500 per day).  If you have an API key for paid
geocoding from Google, set it in the API key section.

Addresses for geocoding can be specified in a list of strings "addresses". In this script, addresses
come from a csv file with a column "Address". Adjust the code to your own requirements as needed.

After every 500 successul geocode operations, a temporary file with results is recorded in case of
script failure / loss of connection later.

Addresses and data are held in memory, so this script may need to be adjusted to process files line
by line if you are processing millions of entries.

Shane Lynn
5th November 2016
"""

import pandas as pd
import requests
import logging
import time

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

#------------------ CONFIGURATION -------------------------------

# Set your Google API key here.
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/,
# the daily limit will be 2500, but at a much faster rate.
# Example: API_KEY = 'AIzaSyC9azed9tLdjpZNjg2_kVePWvMIBq154eA'
API_KEY = None
# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30
# Set your output file name here.
output_filename = '/content/output-2015.csv'
# Set your input file here
input_filename = "/content/PPR-2015.csv"
# Specify the column name in your input data that contains addresses here
address_column_name = "Address"
# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = False

#------------------ DATA LOADING --------------------------------

# Read the data to a Pandas Dataframe
data = pd.read_csv(input_filename, encoding='utf8')

if address_column_name not in data.columns:
	raise ValueError("Missing Address column in input data")

# Form a list of addresses for geocoding:
# Make a big list of all of the addresses to be processed.
addresses = data[address_column_name].tolist()

# **** DEMO DATA / IRELAND SPECIFIC! ****
# We know that these addresses are in Ireland, and there's a column for county, so add this for accuracy.
# (remove this line / alter for your own dataset)
addresses = (data[address_column_name] + ',' + data['County'] + ',Ireland').tolist()


#------------------	FUNCTION DEFINITIONS ------------------------

def get_google_results(address, api_key=None, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.

    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.

    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google.
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)

    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()

    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components')
                                  if 'postal_code' in x.get('types')])
        }

    # Append some other details:
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results

    return output

#------------------ PROCESSING LOOP -----------------------------

# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
  logger.warning("There was an error when testing the Google Geocoder.")
  #raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True

        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} address".format(len(results), len(addresses)))

    # Every 500 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

# All done
logger.info("Finished geocoding all addresses")
# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:root:Geocoded: MOUNTPILL, TOMHAGGARD, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: MOUNTPILL, TOMHAGGARD, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: MOUNTPILL, TOMHAGGARD, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: MOUNTPILL, TOMHAGGARD, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: MOUNTPILL, TOMHAGGARD, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=NO.%2010%20GLASHEEN,%20DRUMLISH,%20COUNTY%20LONGFORD,Longford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=NO.%2010%20GLASHEEN,%20DRUMLISH,%20COUNTY%20LONGFORD,Longford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=NO.%2010%20GLASHEEN,%20DRUMLISH,%20COUNTY%20LONGFORD,Longford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=NO.%2010%20GLASHEEN,%20DRUMLISH,%20COUNTY%20LONGFORD,Longford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=NO.%2010%20GLASHEEN,%20DRUMLISH,%20COUNTY%20LONGFORD,Longford,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Error geocoding NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Error geocoding NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Error geocoding NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Error geocoding NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Geocoded: NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Geocoded: NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Geocoded: NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# Geocoded: NO. 10 GLASHEEN, DRUMLISH, COUNTY LONGFORD,Longford,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=No.%20142%20Clochran,%20Kilcloghans,%20Tuam,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=No.%20142%20Clochran,%20Kilcloghans,%20Tuam,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=No.%20142%20Clochran,%20Kilcloghans,%20Tuam,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=No.%20142%20Clochran,%20Kilcloghans,%20Tuam,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=No.%20142%20Clochran,%20Kilcloghans,%20Tuam,Galway,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Error geocoding No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Error geocoding No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Error geocoding No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Error geocoding No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Geocoded: No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Geocoded: No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Geocoded: No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# Geocoded: No. 142 Clochran, Kilcloghans, Tuam,Galway,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Number%201%20Engine%20House,%20Dargan's%20Way%20Railway%20Avenue,%20Sutton,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Number%201%20Engine%20House,%20Dargan's%20Way%20Railway%20Avenue,%20Sutton,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Number%201%20Engine%20House,%20Dargan's%20Way%20Railway%20Avenue,%20Sutton,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Number%201%20Engine%20House,%20Dargan's%20Way%20Railway%20Avenue,%20Sutton,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Number%201%20Engine%20House,%20Dargan's%20Way%20Railway%20Avenue,%20Sutton,Dublin,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Error geocoding Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Error geocoding Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Error geocoding Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Error geocoding Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Geocoded: Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Geocoded: Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Geocoded: Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# Geocoded: Number 1 Engine House, Dargan's Way Railway Avenue, Sutton,Dublin,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=PEPPARDS%20HILL,%20DUBLIN%20RD,%20KINGSCOURT,Cavan,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=PEPPARDS%20HILL,%20DUBLIN%20RD,%20KINGSCOURT,Cavan,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=PEPPARDS%20HILL,%20DUBLIN%20RD,%20KINGSCOURT,Cavan,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=PEPPARDS%20HILL,%20DUBLIN%20RD,%20KINGSCOURT,Cavan,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=PEPPARDS%20HILL,%20DUBLIN%20RD,%20KINGSCOURT,Cavan,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Error geocoding PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Error geocoding PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Error geocoding PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Error geocoding PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Geocoded: PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Geocoded: PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Geocoded: PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# Geocoded: PEPPARDS HILL, DUBLIN RD, KINGSCOURT,Cavan,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RATHCONNELL%20WOOD,%20NURNEY,%20KILDARE,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RATHCONNELL%20WOOD,%20NURNEY,%20KILDARE,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RATHCONNELL%20WOOD,%20NURNEY,%20KILDARE,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RATHCONNELL%20WOOD,%20NURNEY,%20KILDARE,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RATHCONNELL%20WOOD,%20NURNEY,%20KILDARE,Kildare,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Error geocoding RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Error geocoding RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Error geocoding RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Error geocoding RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Geocoded: RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Geocoded: RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Geocoded: RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# Geocoded: RATHCONNELL WOOD, NURNEY, KILDARE,Kildare,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RENVILLE%20EAST,%20ORANMORE,%20GALWAY,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RENVILLE%20EAST,%20ORANMORE,%20GALWAY,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RENVILLE%20EAST,%20ORANMORE,%20GALWAY,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RENVILLE%20EAST,%20ORANMORE,%20GALWAY,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RENVILLE%20EAST,%20ORANMORE,%20GALWAY,Galway,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Error geocoding RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Error geocoding RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Error geocoding RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Error geocoding RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Geocoded: RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Geocoded: RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Geocoded: RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# Geocoded: RENVILLE EAST, ORANMORE, GALWAY,Galway,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RIGSDALE,%20BALLINHASSIG,%20CO%20CORK,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RIGSDALE,%20BALLINHASSIG,%20CO%20CORK,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RIGSDALE,%20BALLINHASSIG,%20CO%20CORK,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RIGSDALE,%20BALLINHASSIG,%20CO%20CORK,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=RIGSDALE,%20BALLINHASSIG,%20CO%20CORK,Cork,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Error geocoding RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Error geocoding RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Error geocoding RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Error geocoding RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Geocoded: RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Geocoded: RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Geocoded: RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# Geocoded: RIGSDALE, BALLINHASSIG, CO CORK,Cork,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ROCKVILLA,%20WESTERN%20RD,%20CLONMEL,Tipperary,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ROCKVILLA,%20WESTERN%20RD,%20CLONMEL,Tipperary,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ROCKVILLA,%20WESTERN%20RD,%20CLONMEL,Tipperary,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ROCKVILLA,%20WESTERN%20RD,%20CLONMEL,Tipperary,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ROCKVILLA,%20WESTERN%20RD,%20CLONMEL,Tipperary,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Error geocoding ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Error geocoding ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Error geocoding ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Error geocoding ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Geocoded: ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Geocoded: ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Geocoded: ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# Geocoded: ROCKVILLA, WESTERN RD, CLONMEL,Tipperary,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Rosedale,%2033%20Amberley%20Drive,%20Amberley%20%20Grange%20%20Cork,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Rosedale,%2033%20Amberley%20Drive,%20Amberley%20%20Grange%20%20Cork,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Rosedale,%2033%20Amberley%20Drive,%20Amberley%20%20Grange%20%20Cork,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Rosedale,%2033%20Amberley%20Drive,%20Amberley%20%20Grange%20%20Cork,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Rosedale,%2033%20Amberley%20Drive,%20Amberley%20%20Grange%20%20Cork,Cork,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Error geocoding Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Error geocoding Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Error geocoding Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Error geocoding Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Geocoded: Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Geocoded: Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Geocoded: Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# Geocoded: Rosedale, 33 Amberley Drive, Amberley  Grange  Cork,Cork,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SEA%20BANK%20COURT,%20MARINE%20PARADE,%20SANDYCOVE,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SEA%20BANK%20COURT,%20MARINE%20PARADE,%20SANDYCOVE,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SEA%20BANK%20COURT,%20MARINE%20PARADE,%20SANDYCOVE,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SEA%20BANK%20COURT,%20MARINE%20PARADE,%20SANDYCOVE,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SEA%20BANK%20COURT,%20MARINE%20PARADE,%20SANDYCOVE,Dublin,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SEA BANK COURT, MARINE PARADE, SANDYCOVE,Dublin,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SKELLIGS%20MANOR,%20SHIELMARTIN%20RD,%20SUTTON,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SKELLIGS%20MANOR,%20SHIELMARTIN%20RD,%20SUTTON,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SKELLIGS%20MANOR,%20SHIELMARTIN%20RD,%20SUTTON,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SKELLIGS%20MANOR,%20SHIELMARTIN%20RD,%20SUTTON,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=SKELLIGS%20MANOR,%20SHIELMARTIN%20RD,%20SUTTON,Dublin,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Error geocoding SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# Geocoded: SKELLIGS MANOR, SHIELMARTIN RD, SUTTON,Dublin,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ST%20PATRICKS%20VALLEY,%20WICKLOW,%20WICKLOW,Wicklow,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ST%20PATRICKS%20VALLEY,%20WICKLOW,%20WICKLOW,Wicklow,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ST%20PATRICKS%20VALLEY,%20WICKLOW,%20WICKLOW,Wicklow,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ST%20PATRICKS%20VALLEY,%20WICKLOW,%20WICKLOW,Wicklow,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ST%20PATRICKS%20VALLEY,%20WICKLOW,%20WICKLOW,Wicklow,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Error geocoding ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Error geocoding ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Error geocoding ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Error geocoding ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Geocoded: ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Geocoded: ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Geocoded: ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# Geocoded: ST PATRICKS VALLEY, WICKLOW, WICKLOW,Wicklow,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=station%20Road,%20Ballinasloe,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=station%20Road,%20Ballinasloe,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=station%20Road,%20Ballinasloe,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=station%20Road,%20Ballinasloe,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=station%20Road,%20Ballinasloe,Galway,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Error geocoding station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Error geocoding station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Error geocoding station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Error geocoding station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Geocoded: station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Geocoded: station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Geocoded: station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# Geocoded: station Road, Ballinasloe,Galway,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TARA,%20PASS%20RD,%20MEELICK,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TARA,%20PASS%20RD,%20MEELICK,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TARA,%20PASS%20RD,%20MEELICK,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TARA,%20PASS%20RD,%20MEELICK,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TARA,%20PASS%20RD,%20MEELICK,Limerick,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Error geocoding TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Error geocoding TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Error geocoding TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Error geocoding TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Geocoded: TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Geocoded: TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Geocoded: TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# Geocoded: TARA, PASS RD, MEELICK,Limerick,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=The%20Hill,%20Kilmallock,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=The%20Hill,%20Kilmallock,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=The%20Hill,%20Kilmallock,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=The%20Hill,%20Kilmallock,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=The%20Hill,%20Kilmallock,Limerick,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Error geocoding The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Error geocoding The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Error geocoding The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Error geocoding The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Geocoded: The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Geocoded: The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Geocoded: The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# Geocoded: The Hill, Kilmallock,Limerick,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TULLIG%20FARM,%20TULLIG,%20LEAP,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TULLIG%20FARM,%20TULLIG,%20LEAP,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TULLIG%20FARM,%20TULLIG,%20LEAP,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TULLIG%20FARM,%20TULLIG,%20LEAP,Cork,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=TULLIG%20FARM,%20TULLIG,%20LEAP,Cork,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Error geocoding TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Error geocoding TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Error geocoding TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Error geocoding TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Geocoded: TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Geocoded: TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Geocoded: TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# Geocoded: TULLIG FARM, TULLIG, LEAP,Cork,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WHITE%20GATES,%20UPPER%20ROSSAVEAL,%20BALLYNAHOWN,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WHITE%20GATES,%20UPPER%20ROSSAVEAL,%20BALLYNAHOWN,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WHITE%20GATES,%20UPPER%20ROSSAVEAL,%20BALLYNAHOWN,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WHITE%20GATES,%20UPPER%20ROSSAVEAL,%20BALLYNAHOWN,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WHITE%20GATES,%20UPPER%20ROSSAVEAL,%20BALLYNAHOWN,Galway,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Error geocoding WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Error geocoding WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Error geocoding WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Error geocoding WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Geocoded: WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Geocoded: WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Geocoded: WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# Geocoded: WHITE GATES, UPPER ROSSAVEAL, BALLYNAHOWN,Galway,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WILLOW%20LODGE,%20MAREE%20VILLAGE,%20ORANMORE,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WILLOW%20LODGE,%20MAREE%20VILLAGE,%20ORANMORE,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WILLOW%20LODGE,%20MAREE%20VILLAGE,%20ORANMORE,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WILLOW%20LODGE,%20MAREE%20VILLAGE,%20ORANMORE,Galway,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=WILLOW%20LODGE,%20MAREE%20VILLAGE,%20ORANMORE,Galway,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Error geocoding WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Error geocoding WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Error geocoding WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Error geocoding WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Geocoded: WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Geocoded: WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Geocoded: WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# Geocoded: WILLOW LODGE, MAREE VILLAGE, ORANMORE,Galway,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%202%204%205%207%208%209%2010%2011%2012%20WALNUT%20HOUSE,%20Commercial%20Units%201-5%20Walnut%20House,%20Turnpike%20%20Ennis,Clare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%202%204%205%207%208%209%2010%2011%2012%20WALNUT%20HOUSE,%20Commercial%20Units%201-5%20Walnut%20House,%20Turnpike%20%20Ennis,Clare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%202%204%205%207%208%209%2010%2011%2012%20WALNUT%20HOUSE,%20Commercial%20Units%201-5%20Walnut%20House,%20Turnpike%20%20Ennis,Clare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%202%204%205%207%208%209%2010%2011%2012%20WALNUT%20HOUSE,%20Commercial%20Units%201-5%20Walnut%20House,%20Turnpike%20%20Ennis,Clare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%202%204%205%207%208%209%2010%2011%2012%20WALNUT%20HOUSE,%20Commercial%20Units%201-5%20Walnut%20House,%20Turnpike%20%20Ennis,Clare,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Error geocoding 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Error geocoding 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Error geocoding 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Error geocoding 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Geocoded: 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Geocoded: 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Geocoded: 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# Geocoded: 1 2 4 5 7 8 9 10 11 12 WALNUT HOUSE, Commercial Units 1-5 Walnut House, Turnpike  Ennis,Clare,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Berryfields,%20Ferns%20Lower,%20Ferns,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Berryfields,%20Ferns%20Lower,%20Ferns,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Berryfields,%20Ferns%20Lower,%20Ferns,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Berryfields,%20Ferns%20Lower,%20Ferns,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Berryfields,%20Ferns%20Lower,%20Ferns,Wexford,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Error geocoding 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Error geocoding 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Error geocoding 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Error geocoding 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Geocoded: 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Geocoded: 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Geocoded: 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# Geocoded: 1 Berryfields, Ferns Lower, Ferns,Wexford,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Elder%20Heath%20Avenue,%20Kiltipper%20Road,%20Tallaght,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Elder%20Heath%20Avenue,%20Kiltipper%20Road,%20Tallaght,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Elder%20Heath%20Avenue,%20Kiltipper%20Road,%20Tallaght,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Elder%20Heath%20Avenue,%20Kiltipper%20Road,%20Tallaght,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20Elder%20Heath%20Avenue,%20Kiltipper%20Road,%20Tallaght,Dublin,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 1 Elder Heath Avenue, Kiltipper Road, Tallaght,Dublin,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20STRAFFAN%20WAY,%20SHERLOCKSTOWN%20RD,%20SALLINS,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20STRAFFAN%20WAY,%20SHERLOCKSTOWN%20RD,%20SALLINS,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20STRAFFAN%20WAY,%20SHERLOCKSTOWN%20RD,%20SALLINS,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20STRAFFAN%20WAY,%20SHERLOCKSTOWN%20RD,%20SALLINS,Kildare,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20STRAFFAN%20WAY,%20SHERLOCKSTOWN%20RD,%20SALLINS,Kildare,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Error geocoding 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Error geocoding 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Error geocoding 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Error geocoding 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Geocoded: 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Geocoded: 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Geocoded: 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# Geocoded: 1 STRAFFAN WAY, SHERLOCKSTOWN RD, SALLINS,Kildare,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20THE%20MAPLES,%20THOMAS%20ST,%20DROGHEDA,Louth,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20THE%20MAPLES,%20THOMAS%20ST,%20DROGHEDA,Louth,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20THE%20MAPLES,%20THOMAS%20ST,%20DROGHEDA,Louth,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20THE%20MAPLES,%20THOMAS%20ST,%20DROGHEDA,Louth,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=1%20THE%20MAPLES,%20THOMAS%20ST,%20DROGHEDA,Louth,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Error geocoding 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Error geocoding 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Error geocoding 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Error geocoding 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Geocoded: 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Geocoded: 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Geocoded: 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# Geocoded: 1 THE MAPLES, THOMAS ST, DROGHEDA,Louth,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=10%20D%20NEWTOWN%20PARK,%20TALLAGHT,%20DUBLIN%2024,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=10%20D%20NEWTOWN%20PARK,%20TALLAGHT,%20DUBLIN%2024,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=10%20D%20NEWTOWN%20PARK,%20TALLAGHT,%20DUBLIN%2024,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=10%20D%20NEWTOWN%20PARK,%20TALLAGHT,%20DUBLIN%2024,Dublin,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=10%20D%20NEWTOWN%20PARK,%20TALLAGHT,%20DUBLIN%2024,Dublin,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Error geocoding 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# Geocoded: 10 D NEWTOWN PARK, TALLAGHT, DUBLIN 24,Dublin,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=10%20PRIORY%20DR,%20STILLORGAN,%20DUBLIN,Dublin,Ireland HTTP/1.1" 200 237
# ...
# Error geocoding APT 5, BARNA VILLAGE CENTRE, SEAPOINT,Galway,Ireland: REQUEST_DENIED
# Error geocoding APT 5, BARNA VILLAGE CENTRE, SEAPOINT,Galway,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: APT 5, BARNA VILLAGE CENTRE, SEAPOINT,Galway,Ireland: REQUEST_DENIED
# Geocoded: APT 5, BARNA VILLAGE CENTRE, SEAPOINT,Galway,Ireland: REQUEST_DENIED
# Geocoded: APT 5, BARNA VILLAGE CENTRE, SEAPOINT,Galway,Ireland: REQUEST_DENIED
# Geocoded: APT 5, BARNA VILLAGE CENTRE, SEAPOINT,Galway,Ireland: REQUEST_DENIED
# Geocoded: APT 5, BARNA VILLAGE CENTRE, SEAPOINT,Galway,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=APT%2064%20BLOCK%20C,%20BAILIS%20VILLAGE,%20JOHNSTOWN,Meath,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=APT%2064%20BLOCK%20C,%20BAILIS%20VILLAGE,%20JOHNSTOWN,Meath,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=APT%2064%20BLOCK%20C,%20BAILIS%20VILLAGE,%20JOHNSTOWN,Meath,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=APT%2064%20BLOCK%20C,%20BAILIS%20VILLAGE,%20JOHNSTOWN,Meath,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=APT%2064%20BLOCK%20C,%20BAILIS%20VILLAGE,%20JOHNSTOWN,Meath,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Error geocoding APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Error geocoding APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Error geocoding APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Error geocoding APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Geocoded: APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Geocoded: APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Geocoded: APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# Geocoded: APT 64 BLOCK C, BAILIS VILLAGE, JOHNSTOWN,Meath,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARD,%20GEASHILL,%20CO%20OFFALY,Offaly,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARD,%20GEASHILL,%20CO%20OFFALY,Offaly,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARD,%20GEASHILL,%20CO%20OFFALY,Offaly,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARD,%20GEASHILL,%20CO%20OFFALY,Offaly,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARD,%20GEASHILL,%20CO%20OFFALY,Offaly,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Error geocoding ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Error geocoding ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Error geocoding ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Error geocoding ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Geocoded: ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Geocoded: ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Geocoded: ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# Geocoded: ARD, GEASHILL, CO OFFALY,Offaly,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARNESTOWN,%20NEW%20ROSS,%20WEXFORD,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARNESTOWN,%20NEW%20ROSS,%20WEXFORD,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARNESTOWN,%20NEW%20ROSS,%20WEXFORD,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARNESTOWN,%20NEW%20ROSS,%20WEXFORD,Wexford,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=ARNESTOWN,%20NEW%20ROSS,%20WEXFORD,Wexford,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Error geocoding ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Error geocoding ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Error geocoding ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Error geocoding ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# Geocoded: ARNESTOWN, NEW ROSS, WEXFORD,Wexford,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=AVOCA,%20NEWTOWN,%20CASTLETROY,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=AVOCA,%20NEWTOWN,%20CASTLETROY,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=AVOCA,%20NEWTOWN,%20CASTLETROY,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=AVOCA,%20NEWTOWN,%20CASTLETROY,Limerick,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=AVOCA,%20NEWTOWN,%20CASTLETROY,Limerick,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Error geocoding AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Error geocoding AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Error geocoding AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Error geocoding AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Geocoded: AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Geocoded: AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Geocoded: AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# Geocoded: AVOCA, NEWTOWN, CASTLETROY,Limerick,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Ballinfull,%20Cliffoney,Sligo,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Ballinfull,%20Cliffoney,Sligo,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Ballinfull,%20Cliffoney,Sligo,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Ballinfull,%20Cliffoney,Sligo,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=Ballinfull,%20Cliffoney,Sligo,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Error geocoding Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Error geocoding Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Error geocoding Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Error geocoding Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Geocoded: Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Geocoded: Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Geocoded: Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# Geocoded: Ballinfull, Cliffoney,Sligo,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=BALLINTUBBERT%20HOUSE,%20BALLINTUBBERT,%20ATHY,Laois,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=BALLINTUBBERT%20HOUSE,%20BALLINTUBBERT,%20ATHY,Laois,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=BALLINTUBBERT%20HOUSE,%20BALLINTUBBERT,%20ATHY,Laois,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=BALLINTUBBERT%20HOUSE,%20BALLINTUBBERT,%20ATHY,Laois,Ireland HTTP/1.1" 200 237
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=BALLINTUBBERT%20HOUSE,%20BALLINTUBBERT,%20ATHY,Laois,Ireland HTTP/1.1" 200 237
# WARNING:root:Error geocoding BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Error geocoding BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Error geocoding BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Error geocoding BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Error geocoding BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# DEBUG:root:Geocoded: BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Geocoded: BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Geocoded: BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Geocoded: BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# Geocoded: BALLINTUBBERT HOUSE, BALLINTUBBERT, ATHY,Laois,Ireland: REQUEST_DENIED
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# Starting new HTTPS connection (1): maps.googleapis.com:443
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1d3590ea9620> in <cell line: 140>()
#     144         # Geocode the address with google
#     145         try:
# --> 146             geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
#     147         except Exception as e:
#     148             logger.exception(e)
#
# <ipython-input-4-1d3590ea9620> in get_google_results(address, api_key, return_full_response)
#      90
#      91     # Ping google for the reuslts:
# ---> 92     results = requests.get(geocode_url)
#      93     # Results will be in JSON format - convert to dict using requests functionality
#      94     results = results.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712
#     713             # Make the request on the httplib connection object.
# --> 714             httplib_response = self._make_request(
#     715                 conn,
#     716                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401         # Trigger any extra validation we need to do.
#     402         try:
# --> 403             self._validate_conn(conn)
#     404         except (SocketTimeout, BaseSSLError) as e:
#     405             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1051         # Force connect early to allow us to validate the connection.
#    1052         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053             conn.connect()
#    1054
#    1055         if not conn.is_verified:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     417             context.load_default_certs()
#     418
# --> 419         self.sock = ssl_wrap_socket(
#     420             sock=conn,
#     421             keyfile=self.key_file,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400     if ca_certs or ca_cert_dir or ca_cert_data:
#     401         try:
# --> 402             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403         except (IOError, OSError) as e:
#     404             raise SSLError(e)
#
# KeyboardInterrupt:
