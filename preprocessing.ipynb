# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
filename = "priceoye-customer-addresses-ai-model - address updated.csv"
df = pd.read_csv(filename, encoding='utf-8')
df.head()
# Out:
#        id                                            address  \
# 0  446138                    H E 86-3 Fatihabad Lahore Cantt
# 1  445160           Cavalry ground street 1 villa 1A NA Home
# 2  444253  House No. 152-A Street No 6 Block A, Nishat Co...
# 3  444177  House no E96d Ali lane street no 7 cavalry gro...
# 4  444163  House no E96d Ali lane street no 7 cavalry gro...
#
#                        area            city     status      date_create  \
# 0  Cavalry Ground Extension  Lahore - Cantt  delivered  5/17/2023 15:12
# 1  Cavalry Ground Extension  Lahore - Cantt  delivered  5/16/2023 16:10
# 2             Nishat Colony  Lahore - Cantt  delivered  5/15/2023 18:03
# 3  Cavalry Ground Extension  Lahore - Cantt  delivered  5/15/2023 16:55
# 4  Cavalry Ground Extension  Lahore - Cantt  delivered  5/15/2023 16:46
#
#   Address Status (complete, incomplete, incorrect)
# 0                                         Complete
# 1                                         Complete
# 2                                         Complete
# 3                                         Complete
# 4                                         Complete

# %%
# Rename the Address Column to Address Status
df.rename(columns={'Address Status (complete, incomplete, incorrect)':'Address Status'}, inplace=True)

# Drop the columns that are not needed
df.drop(['id', 'status', 'date_create'], axis=1, inplace=True)

df.head()
# Out:
#                                              address  \
# 0                    H E 86-3 Fatihabad Lahore Cantt
# 1           Cavalry ground street 1 villa 1A NA Home
# 2  House No. 152-A Street No 6 Block A, Nishat Co...
# 3  House no E96d Ali lane street no 7 cavalry gro...
# 4  House no E96d Ali lane street no 7 cavalry gro...
#
#                        area            city Address Status
# 0  Cavalry Ground Extension  Lahore - Cantt       Complete
# 1  Cavalry Ground Extension  Lahore - Cantt       Complete
# 2             Nishat Colony  Lahore - Cantt       Complete
# 3  Cavalry Ground Extension  Lahore - Cantt       Complete
# 4  Cavalry Ground Extension  Lahore - Cantt       Complete

# %%
# Check if there are any null values in the dataset
df.isnull().sum()

# Drop the rows with null values
df.dropna(inplace=True)

# %%
df['Address Status'].value_counts()
# Out:
# Complete       7907
# Incomplete     1233
# Complete        525
# Incomplete      220
# Incorrect        66
# Incorrect        49
# Name: Address Status, dtype: int64

# %%
# Create new columns for the city name and Area Category
CityAreaCategory = df['city'].str.split('-')
df['City'] = CityAreaCategory.str[0]
df['Area Category'] = CityAreaCategory.str[1]

# drop the city column
df.drop('city', axis=1, inplace=True)

df.head()
# Out:
#                                              address  \
# 0                    H E 86-3 Fatihabad Lahore Cantt
# 1           Cavalry ground street 1 villa 1A NA Home
# 2  House No. 152-A Street No 6 Block A, Nishat Co...
# 3  House no E96d Ali lane street no 7 cavalry gro...
# 4  House no E96d Ali lane street no 7 cavalry gro...
#
#                        area Address Status     City Area Category
# 0  Cavalry Ground Extension       Complete  Lahore          Cantt
# 1  Cavalry Ground Extension       Complete  Lahore          Cantt
# 2             Nishat Colony       Complete  Lahore          Cantt
# 3  Cavalry Ground Extension       Complete  Lahore          Cantt
# 4  Cavalry Ground Extension       Complete  Lahore          Cantt

# %%
df['City'].value_counts()
# Out:
# Lahore         3558
# Karachi        3522
# Islamabad      1506
# Rawalpindi     1414
# Name: City, dtype: int64

# %%
# Convert the df to lowercase
df['address'] = df['address'].str.lower()
df['City'] = df['City'].str.lower()
df['area'] = df['area'].str.lower()
df['Area Category'] = df['Area Category'].str.lower()
df['Address Status'] = df['Address Status'].str.lower()

# Remove the leading and trailing spaces from the df
df['address'] = df['address'].str.strip()
df['City'] = df['City'].str.strip()
df['area'] = df['area'].str.strip()
df['Area Category'] = df['Area Category'].str.strip()
df['Address Status'] = df['Address Status'].str.strip()

df.head()
# Out:
#                                              address  \
# 0                    h e 86-3 fatihabad lahore cantt
# 1           cavalry ground street 1 villa 1a na home
# 2  house no. 152-a street no 6 block a, nishat co...
# 3  house no e96d ali lane street no 7 cavalry gro...
# 4  house no e96d ali lane street no 7 cavalry gro...
#
#                        area Address Status    City Area Category
# 0  cavalry ground extension       complete  lahore         cantt
# 1  cavalry ground extension       complete  lahore         cantt
# 2             nishat colony       complete  lahore         cantt
# 3  cavalry ground extension       complete  lahore         cantt
# 4  cavalry ground extension       complete  lahore         cantt

# %%
df['Address Status'].value_counts()
# Out:
# complete      8432
# incomplete    1453
# incorrect      115
# Name: Address Status, dtype: int64

# %%
# Function to remove punctuation
# This function will match and replace all characters that are not words, spaces, or hyphens.
# This way, it will preserve the house numbers that include hyphens followed by alphabetic characters (152-A).

def remove_punctuation(text):
    return re.sub(r'[^\w\s-]', '', text)

# Function to remove no. (abbreviation for number)
# This function will match and replace all instances of the abbreviation for no. (number) with an empty string.

def remove_no(text):
    return re.sub(r'\bno\b', '', text)

# Function to insert space between alphabet and digit
# It is used to insert a space between an alphabet and a digit, and a digit and an alphabet regardless of whether the alphabet comes before or the digit.
def insert_space_between_alphabet_and_digit(address):
    address = re.sub(r'([a-zA-Z])(?=\d)', r'\1 ', address)
    address = re.sub(r'(?<=\d)([a-zA-Z])', r' \1', address)
    return address

# Here, the re.sub() function is used with a regular expression that matches the word you want to match (word_to_match)
# followed by any characters (.*$) until the end of the string. 
# The matched word and everything after it are replaced with an empty string
def remove_text_after_word(text, word_to_match):
    return re.sub(rf'\b{re.escape(word_to_match)}\b.*$', '', text)

# %%
# Apply the punctuation function to the 'address' column
df['address'] = df['address'].apply(remove_punctuation)

# Apply the remove_no function to the 'address' column
df['address'] = df['address'].apply(remove_no)

# Apply the insert_space function to the 'address' column
df['address'] = df['address'].apply(insert_space_between_alphabet_and_digit)

# %%
# Abbreviation mapping dictionary
abbreviations = {
    'st': 'street',
    'ave': 'avenue',
    'apt': 'apartment',
    'rd': 'road',
    'h': 'house',
    'hse': 'house',
    'blvd': 'boulevard',
    'apt': 'apartment',
    'bldg': 'building',
    'pl': 'place',
    'dr': 'drive',
    'ln': 'lane',
    'pkwy': 'parkway',
    'hw': 'highway',
    'hwy': 'highway',
    'expy': 'expressway',
    'exp': 'expressway',
    'expw': 'expressway',
    'ext': 'extension',
    'n': 'north',
    's': 'south',
    'e': 'east',
    'w': 'west',
    'ft': 'fort',
    'lhr': 'lahore',
    'khi': 'karachi',
    'isb': 'islamabad',
    'rwp': 'rawalpindi',
    'kar': 'karachi',
    'pak': 'pakistan',
    'pnjb': 'punjab',
    'pjb': 'punjab',
    'isl': 'islamabad'
}

# %%
# Replace abbreviations with full forms to standardize the data
for abbrev, full_form in abbreviations.items():
    df['address'] = df['address'].str.replace(r'\b{}\b'.format(abbrev), full_form)
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_16432\2849352148.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['address'] = df['address'].str.replace(r'\b{}\b'.format(abbrev), full_form)

# %%
# Remove more than one spaces in between words
df['address'] = df['address'].str.replace(' +', ' ')
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_16432\1522237486.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['address'] = df['address'].str.replace(' +', ' ')

# %%
df.head(20)
# Out:
#                                               address  \
# 0              house east 86-3 fatihabad lahore cantt
# 1           cavalry ground street 1 villa 1 a na home
# 2          house 152-a street 6 block a nishat colony
# 3   house east 96 d ali lane street 7 cavalry grou...
# 4   house east 96 d ali lane street 7 cavalry grou...
# 5   east-856 b street 2 block g nadirabad ali park...
# 6   house 21 jalal colony harbanspura lahore near ...
# 7   east-572 abu bakar saddique road nishat colony...
# 8   akrambad street 1 house 679 near cavalry groun...
# 9                      cma colony street 6 house 92 b
# 10  east 239 a-3 deen street abid road walton laho...
# 11  akrambad street 1 house 679 near cavalry groun...
# 12  akrambad street 1 house 679 near cavalry groun...
# 13  akrambad street 1 house 679 near cavalry groun...
# 14  house 8 street 5 a-block alfaisal town mian am...
# 15  flat b-22 habib flats habib road cantt lahore ...
# 16  room 1 g mess offrs boqs sarfaraz rafiqui road...
# 17  house 39 executive block divine garden airport...
# 18  house 134-b paf new officers colony zarrar sha...
# 19  east 239 a-3 deen street abid road walton laho...
#
#                              area Address Status    City Area Category
# 0        cavalry ground extension       complete  lahore         cantt
# 1        cavalry ground extension       complete  lahore         cantt
# 2                   nishat colony       complete  lahore         cantt
# 3        cavalry ground extension       complete  lahore         cantt
# 4        cavalry ground extension       complete  lahore         cantt
# 5                    airport road       complete  lahore         cantt
# 6   aziz bhatti road lahore cantt       complete  lahore         cantt
# 7                   nishat colony       complete  lahore         cantt
# 8        cavalry ground extension       complete  lahore         cantt
# 9         shami road lahore cantt       complete  lahore         cantt
# 10                      r.a bazar       complete  lahore         cantt
# 11       cavalry ground extension       complete  lahore         cantt
# 12       cavalry ground extension       complete  lahore         cantt
# 13       cavalry ground extension       complete  lahore         cantt
# 14                    sadar cantt       complete  lahore         cantt
# 15       sarwar road lahore cantt       complete  lahore         cantt
# 16           sarfraz rafiqui road       complete  lahore         cantt
# 17                   airport road       complete  lahore         cantt
# 18                    sadar cantt       complete  lahore         cantt
# 19       cavalry ground extension       complete  lahore         cantt

# %%
df.tail(20)
# Out:
#                                                 address           area  \
# 9980   makhi masjid near burma shell depot dhoke munshi       scheme 1
# 9981                                  paf base nur khan      22 chungi
# 9982  babu mohala saddiq near babu market street 23 ...        phase 1
# 9983  house 654 street 06 model town humak sharqi is...        phase 1
# 9984      rcci industrial estate plot 44 street south 1        phase 5
# 9985  room 60 nab course sawan hostel block 5 a poli...        phase 1
# 9986  milan paint shop 40 al hajj market near al jan...        phase 2
# 9987                             giga mall ground floor        phase 5
# 9988  near giga mall dha face 2 gate 4 oppsite agoch...        phase 2
# 9989  babia banglows near abdul rehman mosque mohala...        phase 1
# 9990                             giga mall ground floor    dhoke ratta
# 9991  airport housing society sactor 4 street 13 blo...        phase 4
# 9992  home 137 street 9 mangral model town rawalpind...        phase 1
# 9993                   ali medical f 8 markuz islamabad    peshawar rd
# 9994                   ali medical f 8 markuz islamabad    peshawar rd
# 9995  d 11 ground floor taj mehal market city saddar...     gawalmandi
# 9996          punjab watch co u-51 rajabazar rawalpindi           bani
# 9997  quaid-east-azam colony lane 3 street 6 almaka ...  dhamiyal camp
# 9998  main pwd double road shinka plazafirst floor o...     khanna pul
# 9999  2 nd floor cargo sale office pia booking offic...          sadar
#
#      Address Status        City Area Category
# 9980      incorrect  rawalpindi      chaklala
# 9981      incorrect  rawalpindi        chakri
# 9982      incorrect  rawalpindi           dha
# 9983      incorrect  rawalpindi           dha
# 9984      incorrect  rawalpindi           dha
# 9985      incorrect  rawalpindi           dha
# 9986      incorrect  rawalpindi           dha
# 9987      incorrect  rawalpindi           dha
# 9988      incorrect  rawalpindi           dha
# 9989      incorrect  rawalpindi           dha
# 9990      incorrect  rawalpindi   dhoke ratta
# 9991      incorrect  rawalpindi   ghauri town
# 9992      incorrect  rawalpindi   ghauri town
# 9993      incorrect  rawalpindi         other
# 9994      incorrect  rawalpindi         other
# 9995      incorrect  rawalpindi         other
# 9996      incorrect  rawalpindi         other
# 9997      incorrect  rawalpindi         other
# 9998      incorrect  rawalpindi         other
# 9999      incorrect  rawalpindi         other

# %%
# Perform string matching and replace values in 'address' column
for index, row in df.iterrows():
    
    # Check if whole area name is present in the address
    # If yes, remove it from the address
    # If no, check if prefix of area name is present in the address
    # If yes, remove it from the address
    
    area = row['area']
    area_tokens = area.split()

    if area in row['address']:
        df.at[index, 'address'] = df.at[index, 'address'].replace(area, '')
    elif len(area_tokens) > 1:
        length = len(area_tokens)
        for i in range(length-1, 0, -1):
            # Make new string from the first i tokens
            new_area = ' '.join(area_tokens[:i])

            if new_area in row['address']:
                df.at[index, 'address'] = df.at[index, 'address'].replace(new_area, '')
                break

# %%
# Define the word to match
word_to_match = 'near'

# Remove text after the matched word
df['address'] = df['address'].apply(remove_text_after_word, args=(word_to_match,))

# %%
# Perform string matching and replace values in 'address' column
for index, row in df.iterrows():

    df.at[index, 'address'] = df.at[index, 'address'].replace(row['Area Category'], '')
    df.at[index, 'address'] = df.at[index, 'address'].replace(row['City'], '')
    
    # Remove state and country names from the address as well
    df.at[index, 'address'] = df.at[index, 'address'].replace('punjab', '')
    df.at[index, 'address'] = df.at[index, 'address'].replace('sindh', '')
    df.at[index, 'address'] = df.at[index, 'address'].replace('pakistan', '')

# %%
df.head(20)
# Out:
#                                               address  \
# 0                         house east 86-3 fatihabad
# 1                          street 1 villa 1 a na home
# 2                       house 152-a street 6 block a
# 3   house east 96 d ali lane street 7    khalid ma...
# 4   house east 96 d ali lane street 7    khalid ma...
# 5    east-856 b street 2 block g nadirabad ali park
# 6                 house 21 jalal colony harbanspura
# 7                 east-572 abu bakar saddique road
# 8                        akrambad street 1 house 679
# 9                      cma colony street 6 house 92 b
# 10        east 239 a-3 deen street abid road walton
# 11                       akrambad street 1 house 679
# 12                       akrambad street 1 house 679
# 13                       akrambad street 1 house 679
# 14  house 8 street 5 a-block alfaisal town mian am...
# 15               flat b-22 habib flats habib road
# 16   room 1 g mess offrs boqs sarfaraz rafiqui road
# 17           house 39 executive block divine garden
# 18  house 134-b paf new officers colony zarrar sha...
# 19        east 239 a-3 deen street abid road walton
#
#                              area Address Status    City Area Category
# 0        cavalry ground extension       complete  lahore         cantt
# 1        cavalry ground extension       complete  lahore         cantt
# 2                   nishat colony       complete  lahore         cantt
# 3        cavalry ground extension       complete  lahore         cantt
# 4        cavalry ground extension       complete  lahore         cantt
# 5                    airport road       complete  lahore         cantt
# 6   aziz bhatti road lahore cantt       complete  lahore         cantt
# 7                   nishat colony       complete  lahore         cantt
# 8        cavalry ground extension       complete  lahore         cantt
# 9         shami road lahore cantt       complete  lahore         cantt
# 10                      r.a bazar       complete  lahore         cantt
# 11       cavalry ground extension       complete  lahore         cantt
# 12       cavalry ground extension       complete  lahore         cantt
# 13       cavalry ground extension       complete  lahore         cantt
# 14                    sadar cantt       complete  lahore         cantt
# 15       sarwar road lahore cantt       complete  lahore         cantt
# 16           sarfraz rafiqui road       complete  lahore         cantt
# 17                   airport road       complete  lahore         cantt
# 18                    sadar cantt       complete  lahore         cantt
# 19       cavalry ground extension       complete  lahore         cantt

# %%
# show address column
df.tail(20)
# Out:
#                                                 address           area  \
# 9980                                      makhi masjid        scheme 1
# 9981                                  paf base nur khan      22 chungi
# 9982                                babu mohala saddiq         phase 1
# 9983  house 654 street 06 model town humak sharqi is...        phase 1
# 9984      rcci industrial estate plot 44 street south 1        phase 5
# 9985  room 60 nab course sawan hostel block 5 a poli...        phase 1
# 9986                milan paint shop 40 al hajj market         phase 2
# 9987                             giga mall ground floor        phase 5
# 9988                                                           phase 2
# 9989                                    babia banglows         phase 1
# 9990                             giga mall ground floor    dhoke ratta
# 9991  airport housing society sactor 4 street 13 blo...        phase 4
# 9992             home 137 street 9 mangral model town          phase 1
# 9993                   ali medical f 8 markuz islamabad    peshawar rd
# 9994                   ali medical f 8 markuz islamabad    peshawar rd
# 9995  d 11 ground floor taj mehal market city saddar...     gawalmandi
# 9996                           watch co u-51 rajabazar            bani
# 9997  quaid-east-azam colony lane 3 street 6 almaka ...  dhamiyal camp
# 9998  main pwd double road shinka plazafirst floor o...     khanna pul
# 9999  2 nd floor cargo sale office pia booking offic...          sadar
#
#      Address Status        City Area Category
# 9980      incorrect  rawalpindi      chaklala
# 9981      incorrect  rawalpindi        chakri
# 9982      incorrect  rawalpindi           dha
# 9983      incorrect  rawalpindi           dha
# 9984      incorrect  rawalpindi           dha
# 9985      incorrect  rawalpindi           dha
# 9986      incorrect  rawalpindi           dha
# 9987      incorrect  rawalpindi           dha
# 9988      incorrect  rawalpindi           dha
# 9989      incorrect  rawalpindi           dha
# 9990      incorrect  rawalpindi   dhoke ratta
# 9991      incorrect  rawalpindi   ghauri town
# 9992      incorrect  rawalpindi   ghauri town
# 9993      incorrect  rawalpindi         other
# 9994      incorrect  rawalpindi         other
# 9995      incorrect  rawalpindi         other
# 9996      incorrect  rawalpindi         other
# 9997      incorrect  rawalpindi         other
# 9998      incorrect  rawalpindi         other
# 9999      incorrect  rawalpindi         other

# %%
df.to_csv('preprocessed.csv', index=False)

# %%
# Make deep copy of the original dataframe
df_1 = df.copy()
df_2 = df.copy()

# %%
import requests
import time

API_KEY = 'your_api_key'
BASE_URL = 'https://maps.googleapis.com/maps/api/geocode/json'

MAX_REQUESTS_PER_SECOND = 50

def validate_address(address):
    params = {
        'address': address,
        'key': API_KEY
    }
    response = requests.get(BASE_URL, params=params)
    data = response.json()
    # Process the data to extract coordinates
    location = data.get('results', [])[0].get('geometry', {}).get('location', {})
    latitude = location.get('lat', None)
    longitude = location.get('lng', None)
    return latitude, longitude

df_1['latitude'] = None  # Add a new column to store latitude
df_1['longitude'] = None  # Add a new column to store longitude

count = 0  # Counter to keep track of requests
start_time = time.time()  # Start time of batch processing

# Get no. of rows in DataFrame
num_rows = df_1.shape[0]

for index, row in df_1.iterrows():
    count += 1
    
    if count <= 100 or count >= num_rows - 100:
        address = f"{row['address']}, {row['area']}, {row['Area Category']}, {row['City']}"
        latitude, longitude = validate_address(address=address)
        df_1.at[index, 'latitude'] = latitude
        df_1.at[index, 'longitude'] = longitude

        if count % MAX_REQUESTS_PER_SECOND == 0:
            elapsed_time = time.time() - start_time
            if elapsed_time < 1.0:
                time.sleep(1.0 - elapsed_time)  # Wait for the remaining time
        
            start_time = time.time()  # Reset the start time
    else:
        df_1.at[index, 'latitude'] = None
        df_1.at[index, 'longitude'] = None

# %%
df_1.to_csv('usingGeocodingApi.csv', index=False)

df_1.head(20)
# Out:
#                                               address  \
# 0                         house east 86-3 fatihabad
# 1                          street 1 villa 1 a na home
# 2                       house 152-a street 6 block a
# 3   house east 96 d ali lane street 7    khalid ma...
# 4   house east 96 d ali lane street 7    khalid ma...
# 5    east-856 b street 2 block g nadirabad ali park
# 6                 house 21 jalal colony harbanspura
# 7                 east-572 abu bakar saddique road
# 8                        akrambad street 1 house 679
# 9                      cma colony street 6 house 92 b
# 10        east 239 a-3 deen street abid road walton
# 11                       akrambad street 1 house 679
# 12                       akrambad street 1 house 679
# 13                       akrambad street 1 house 679
# 14  house 8 street 5 a-block alfaisal town mian am...
# 15               flat b-22 habib flats habib road
# 16   room 1 g mess offrs boqs sarfaraz rafiqui road
# 17           house 39 executive block divine garden
# 18  house 134-b paf new officers colony zarrar sha...
# 19        east 239 a-3 deen street abid road walton
#
#                              area Address Status    City Area Category  \
# 0        cavalry ground extension       complete  lahore         cantt
# 1        cavalry ground extension       complete  lahore         cantt
# 2                   nishat colony       complete  lahore         cantt
# 3        cavalry ground extension       complete  lahore         cantt
# 4        cavalry ground extension       complete  lahore         cantt
# 5                    airport road       complete  lahore         cantt
# 6   aziz bhatti road lahore cantt       complete  lahore         cantt
# 7                   nishat colony       complete  lahore         cantt
# 8        cavalry ground extension       complete  lahore         cantt
# 9         shami road lahore cantt       complete  lahore         cantt
# 10                      r.a bazar       complete  lahore         cantt
# 11       cavalry ground extension       complete  lahore         cantt
# 12       cavalry ground extension       complete  lahore         cantt
# 13       cavalry ground extension       complete  lahore         cantt
# 14                    sadar cantt       complete  lahore         cantt
# 15       sarwar road lahore cantt       complete  lahore         cantt
# 16           sarfraz rafiqui road       complete  lahore         cantt
# 17                   airport road       complete  lahore         cantt
# 18                    sadar cantt       complete  lahore         cantt
# 19       cavalry ground extension       complete  lahore         cantt
#
#      latitude  longitude
# 0   31.500407  74.366078
# 1   31.469091  74.392052
# 2     31.4866  74.386192
# 3   31.500011  74.366515
# 4   31.500011  74.366515
# 5   31.480637  74.383764
# 6   31.567462  74.432411
# 7   31.492558  74.392468
# 8   31.500407  74.366078
# 9   31.534328  74.368623
# 10  31.492797  74.368778
# 11  31.500407  74.366078
# 12  31.500407  74.366078
# 13  31.500407  74.366078
# 14  31.551399  74.407771
# 15  31.534824  74.378818
# 16  31.519611  74.388925
# 17  31.503222  74.416655
# 18  31.548531  74.405687
# 19  31.492797  74.368778

# %%
df_1.tail(20)
# Out:
#                                                 address           area  \
# 9980                                      makhi masjid        scheme 1
# 9981                                  paf base nur khan      22 chungi
# 9982                                babu mohala saddiq         phase 1
# 9983  house 654 street 06 model town humak sharqi is...        phase 1
# 9984      rcci industrial estate plot 44 street south 1        phase 5
# 9985  room 60 nab course sawan hostel block 5 a poli...        phase 1
# 9986                milan paint shop 40 al hajj market         phase 2
# 9987                             giga mall ground floor        phase 5
# 9988                                                           phase 2
# 9989                                    babia banglows         phase 1
# 9990                             giga mall ground floor    dhoke ratta
# 9991  airport housing society sactor 4 street 13 blo...        phase 4
# 9992             home 137 street 9 mangral model town          phase 1
# 9993                   ali medical f 8 markuz islamabad    peshawar rd
# 9994                   ali medical f 8 markuz islamabad    peshawar rd
# 9995  d 11 ground floor taj mehal market city saddar...     gawalmandi
# 9996                           watch co u-51 rajabazar            bani
# 9997  quaid-east-azam colony lane 3 street 6 almaka ...  dhamiyal camp
# 9998  main pwd double road shinka plazafirst floor o...     khanna pul
# 9999  2 nd floor cargo sale office pia booking offic...          sadar
#
#      Address Status        City Area Category   latitude  longitude
# 9980      incorrect  rawalpindi      chaklala  33.723888  73.084361
# 9981      incorrect  rawalpindi        chakri   33.61651  73.095136
# 9982      incorrect  rawalpindi           dha  33.565111  73.016914
# 9983      incorrect  rawalpindi           dha  33.538653  73.148237
# 9984      incorrect  rawalpindi           dha  31.462539  74.408593
# 9985      incorrect  rawalpindi           dha  33.544072  73.196911
# 9986      incorrect  rawalpindi           dha  33.559417  73.121683
# 9987      incorrect  rawalpindi           dha  33.528894   73.20874
# 9988      incorrect  rawalpindi           dha  33.559417  73.121683
# 9989      incorrect  rawalpindi           dha  33.565111  73.016914
# 9990      incorrect  rawalpindi   dhoke ratta  33.613884  73.044955
# 9991      incorrect  rawalpindi   ghauri town  33.614694  73.130862
# 9992      incorrect  rawalpindi   ghauri town  33.620533  73.140861
# 9993      incorrect  rawalpindi         other  33.710413  73.042016
# 9994      incorrect  rawalpindi         other  33.710413  73.042016
# 9995      incorrect  rawalpindi         other  33.614211  73.055067
# 9996      incorrect  rawalpindi         other  33.565111  73.016914
# 9997      incorrect  rawalpindi         other  33.534155  73.028721
# 9998      incorrect  rawalpindi         other  33.572655  73.147421
# 9999      incorrect  rawalpindi         other  33.596203  73.047815

# %%
from geopy.geocoders import GoogleV3
import time

API_KEY = 'your_api_key'
MAX_REQUESTS_PER_SECOND = 50

def rate_limited_geocode(address, geolocator):
    location = geolocator.geocode(address)
    return location

df_2['latitude'] = None  # Add a new column to store latitude
df_2['longitude'] = None  # Add a new column to store longitude

geolocator = GoogleV3(api_key=API_KEY)

num_rows = df_2.shape[0]
count = 0

for index, row in df_2.iterrows():

    count += 1

    if not count <= 50 or count >= num_rows - 50:
        continue
    address = f"{row['address']}, {row['area']}, {row['Area Category']}, {row['City']}"
    location = rate_limited_geocode(address, geolocator)
    if location is not None:
        df_2.at[index, 'latitude'] = location.latitude
        df_2.at[index, 'longitude'] = location.longitude

# %%
df_2.to_csv('afterGeoPyLibrary.csv', index=False)

df_2.head(50)
# Out:
#                                               address  \
# 0                         house east 86-3 fatihabad
# 1                          street 1 villa 1 a na home
# 2                       house 152-a street 6 block a
# 3   house east 96 d ali lane street 7    khalid ma...
# 4   house east 96 d ali lane street 7    khalid ma...
# 5    east-856 b street 2 block g nadirabad ali park
# 6                 house 21 jalal colony harbanspura
# 7                 east-572 abu bakar saddique road
# 8                        akrambad street 1 house 679
# 9                      cma colony street 6 house 92 b
# 10        east 239 a-3 deen street abid road walton
# 11                       akrambad street 1 house 679
# 12                       akrambad street 1 house 679
# 13                       akrambad street 1 house 679
# 14  house 8 street 5 a-block alfaisal town mian am...
# 15               flat b-22 habib flats habib road
# 16   room 1 g mess offrs boqs sarfaraz rafiqui road
# 17           house 39 executive block divine garden
# 18  house 134-b paf new officers colony zarrar sha...
# 19        east 239 a-3 deen street abid road walton
# 20  house east 993 street 3 mohalla shahid town na...
# 21        house 710 street 69 bazzaz mohllah  bazar
# 22                 house east 903-1-a mustafa street
# 23        107 f ali view garden phase 3 bedian road
# 24                  east-105 a link 2 new super town
# 25     he-704 street 5 block c ali park bedian road
# 26                                           house 68
# 27                     office 2 floor 1 172  mall of
# 28      house east 197 nabipur lane street 6  walton
# 29                  madiha hamid 181-east street 6
# 30                     sally town east block house 10
# 31             east 31 a street 1 u lane extension
# 32              east 7887 street 3 block f ali park
# 33  147 a eden city   opposite new  adjacent dha p...
# 34                                         322  cant
# 35                    house 4-a old shami apartments
# 36      house east-7884 street no 2 f-block ali park
# 37                                    2 shabbir road
# 38  flat 9 block 3 railway officers flats walton r...
# 39  house 315 a street 32 diggi mohallah  bazar  cant
# 40      east-22 a-10 arain lane street 7  walton road
# 41             21 a ali alam garden lmdc harbanspura
# 42  house 244 d 1 pathano vali gali gulshan park  lhe
# 43                     station headquarters navy 92
# 44  alfaisal town d block bahar shah road house 10...
# 45  house 14 street 1 bhatti floor mill sharimar l...
# 46             house east-2885 street 11 millat road
# 47              house east 849 street 2 block east
# 48                 house 13 street 10 gunj mughalpura
# 49  house 318 street 64-south tajpura road mughalp...
#
#                              area Address Status    City Area Category  \
# 0        cavalry ground extension       complete  lahore         cantt
# 1        cavalry ground extension       complete  lahore         cantt
# 2                   nishat colony       complete  lahore         cantt
# 3        cavalry ground extension       complete  lahore         cantt
# 4        cavalry ground extension       complete  lahore         cantt
# 5                    airport road       complete  lahore         cantt
# 6   aziz bhatti road lahore cantt       complete  lahore         cantt
# 7                   nishat colony       complete  lahore         cantt
# 8        cavalry ground extension       complete  lahore         cantt
# 9         shami road lahore cantt       complete  lahore         cantt
# 10                      r.a bazar       complete  lahore         cantt
# 11       cavalry ground extension       complete  lahore         cantt
# 12       cavalry ground extension       complete  lahore         cantt
# 13       cavalry ground extension       complete  lahore         cantt
# 14                    sadar cantt       complete  lahore         cantt
# 15       sarwar road lahore cantt       complete  lahore         cantt
# 16           sarfraz rafiqui road       complete  lahore         cantt
# 17                   airport road       complete  lahore         cantt
# 18                    sadar cantt       complete  lahore         cantt
# 19       cavalry ground extension       complete  lahore         cantt
# 20                 ferozepur road       complete  lahore         cantt
# 21                    sadar cantt       complete  lahore         cantt
# 22                      r.a bazar       complete  lahore         cantt
# 23                   airport road       complete  lahore         cantt
# 24       cavalry ground extension       complete  lahore         cantt
# 25                   airport road       complete  lahore         cantt
# 26  abid majeed road lahore cantt       complete  lahore         cantt
# 27       tufail road lahore cantt       complete  lahore         cantt
# 28       cavalry ground extension       complete  lahore         cantt
# 29       cavalry ground extension       complete  lahore         cantt
# 30                   airport road       complete  lahore         cantt
# 31       cavalry ground extension       complete  lahore         cantt
# 32                      r.a bazar       complete  lahore         cantt
# 33                   airport road       complete  lahore         cantt
# 34       sarwar road lahore cantt       complete  lahore         cantt
# 35        shami road lahore cantt       complete  lahore         cantt
# 36                      r.a bazar       complete  lahore         cantt
# 37  aziz bhatti road lahore cantt       complete  lahore         cantt
# 38       cavalry ground extension       complete  lahore         cantt
# 39                    sadar cantt       complete  lahore         cantt
# 40       cavalry ground extension       complete  lahore         cantt
# 41                    sadar cantt       complete  lahore         cantt
# 42                  nishat colony       complete  lahore         cantt
# 43        shami road lahore cantt       complete  lahore         cantt
# 44                   airport road       complete  lahore         cantt
# 45                    sadar cantt       complete  lahore         cantt
# 46                 ferozepur road       complete  lahore         cantt
# 47                  nishat colony       complete  lahore         cantt
# 48  aziz bhatti road lahore cantt       complete  lahore         cantt
# 49                    sadar cantt       complete  lahore         cantt
#
#      latitude  longitude
# 0   31.500407  74.366078
# 1   31.469091  74.392052
# 2     31.4866  74.386192
# 3   31.500011  74.366515
# 4   31.500011  74.366515
# 5   31.480637  74.383764
# 6   31.567462  74.432411
# 7   31.492558  74.392468
# 8   31.500407  74.366078
# 9   31.534328  74.368623
# 10  31.492797  74.368778
# 11  31.500407  74.366078
# 12  31.500407  74.366078
# 13  31.500407  74.366078
# 14  31.551399  74.407771
# 15  31.534824  74.378818
# 16  31.519611  74.388925
# 17  31.503222  74.416655
# 18  31.548531  74.405687
# 19  31.492797  74.368778
# 20  31.458615  74.350756
# 21  31.553002  74.373693
# 22  31.497559  74.407993
# 23  31.489912  74.409907
# 24  31.501049  74.376793
# 25  31.458141  74.441368
# 26  31.521966  74.383127
# 27  31.525971  74.379247
# 28  31.496742  74.370134
# 29  31.496838  74.367462
# 30  31.555381  74.410792
# 31  31.500407  74.366078
# 32  31.477863  74.400999
# 33  31.507103  74.442304
# 34  31.528374  74.376562
# 35  31.521991  74.368554
# 36   31.50228  74.407709
# 37  31.528567   74.37444
# 38  31.483313  74.361937
# 39   31.53052  74.417898
# 40  31.493647  74.369795
# 41  31.587464  74.463164
# 42  31.520327  74.410358
# 43  31.534328  74.368623
# 44  31.545276  74.403735
# 45  31.519611  74.388925
# 46  31.539711  74.414464
# 47  31.480637  74.383764
# 48  31.529799  74.383515
# 49  31.559549  74.400554

# %%
df_2.tail(50)
# Out:
#                                                 address  \
# 9950                                                dha
# 9951         valancia town north block valancia heights
# 9952                              village jughain alfa
# 9953                        dahrpindi new airport rod
# 9954                               ghulshan ali colony
# 9955                           millat road yaseen town
# 9956                               pindi   new airport
# 9957  glaxo town anam road 20 km   stylers internati...
# 9958                                                  g
# 9959                                    self collection
# 9960                                                  g
# 9961                                                607
# 9962                                                gss
# 9963                                                618
# 9964                                       jhugia nagra
# 9965                               bhakhawal qabarsatan
# 9966                                                gsd
# 9967                                                  g
# 9968               gajumatadefence road  kacha village
# 9969                                               1124
# 9970                                                446
# 9971  architect mudasir nazar site office aljalil ga...
# 9972  hassan estate and developers chaudary chowk d ...
# 9973  hassan estate and developers chaudary chowk pi...
# 9974                                        ashrafabad
# 9975                                  28 a alhamra town
# 9976                                        sareen city
# 9977  signatures group first floor plot no 2 block-c...
# 9978                      par base nur khan  dohk khaba
# 9979  dhok munshikhan  gahno norani mohla barma shel...
# 9980                                      makhi masjid
# 9981                                  paf base nur khan
# 9982                                babu mohala saddiq
# 9983  house 654 street 06 model town humak sharqi is...
# 9984      rcci industrial estate plot 44 street south 1
# 9985  room 60 nab course sawan hostel block 5 a poli...
# 9986                milan paint shop 40 al hajj market
# 9987                             giga mall ground floor
# 9988
# 9989                                    babia banglows
# 9990                             giga mall ground floor
# 9991  airport housing society sactor 4 street 13 blo...
# 9992             home 137 street 9 mangral model town
# 9993                   ali medical f 8 markuz islamabad
# 9994                   ali medical f 8 markuz islamabad
# 9995  d 11 ground floor taj mehal market city saddar...
# 9996                           watch co u-51 rajabazar
# 9997  quaid-east-azam colony lane 3 street 6 almaka ...
# 9998  main pwd double road shinka plazafirst floor o...
# 9999  2 nd floor cargo sale office pia booking offic...
#
#                                         area Address Status        City  \
# 9950                                 block a      incorrect      lahore
# 9951                     dha rehber phase 11      incorrect      lahore
# 9952                                 phase 8      incorrect      lahore
# 9953                                 phase 8      incorrect      lahore
# 9954                               kb colony      incorrect      lahore
# 9955                                 phase 4      incorrect      lahore
# 9956                                 phase 8      incorrect      lahore
# 9957                               anum road      incorrect      lahore
# 9958                       gulberg 2 block h      incorrect      lahore
# 9959                           madina colony      incorrect      lahore
# 9960                              pepsi stop      incorrect      lahore
# 9961                              ravi block      incorrect      lahore
# 9962                            kareem block      incorrect      lahore
# 9963                            nargis block      incorrect      lahore
# 9964                            kamran block      incorrect      lahore
# 9965                              raza block      incorrect      lahore
# 9966  lahore medical housing society phase 1      incorrect      lahore
# 9967                                 block d      incorrect      lahore
# 9968                               kahna nau      incorrect      lahore
# 9969                                 block c      incorrect      lahore
# 9970                                 block k      incorrect      lahore
# 9971                   rehman garden phase 2      incorrect      lahore
# 9972                         revenue society      incorrect      lahore
# 9973                         revenue society      incorrect      lahore
# 9974                             opf society      incorrect      lahore
# 9975                              nawab town      incorrect      lahore
# 9976                                 phase 8      incorrect  rawalpindi
# 9977                                 phase 1      incorrect  rawalpindi
# 9978                                scheme 3      incorrect  rawalpindi
# 9979                                scheme 3      incorrect  rawalpindi
# 9980                                scheme 1      incorrect  rawalpindi
# 9981                               22 chungi      incorrect  rawalpindi
# 9982                                 phase 1      incorrect  rawalpindi
# 9983                                 phase 1      incorrect  rawalpindi
# 9984                                 phase 5      incorrect  rawalpindi
# 9985                                 phase 1      incorrect  rawalpindi
# 9986                                 phase 2      incorrect  rawalpindi
# 9987                                 phase 5      incorrect  rawalpindi
# 9988                                 phase 2      incorrect  rawalpindi
# 9989                                 phase 1      incorrect  rawalpindi
# 9990                             dhoke ratta      incorrect  rawalpindi
# 9991                                 phase 4      incorrect  rawalpindi
# 9992                                 phase 1      incorrect  rawalpindi
# 9993                             peshawar rd      incorrect  rawalpindi
# 9994                             peshawar rd      incorrect  rawalpindi
# 9995                              gawalmandi      incorrect  rawalpindi
# 9996                                    bani      incorrect  rawalpindi
# 9997                           dhamiyal camp      incorrect  rawalpindi
# 9998                              khanna pul      incorrect  rawalpindi
# 9999                                   sadar      incorrect  rawalpindi
#
#              Area Category latitude longitude
# 9950          canal garden     None      None
# 9951  defence road raiwind     None      None
# 9952                   dha     None      None
# 9953                   dha     None      None
# 9954                   dha     None      None
# 9955                   dha     None      None
# 9956                   dha     None      None
# 9957         ferozpur road     None      None
# 9958               gulberg     None      None
# 9959               gulberg     None      None
# 9960           harbanspura     None      None
# 9961            iqbal town     None      None
# 9962            iqbal town     None      None
# 9963            iqbal town     None      None
# 9964            iqbal town     None      None
# 9965            iqbal town     None      None
# 9966                 jallo     None      None
# 9967            johar town     None      None
# 9968           kasoor road     None      None
# 9969            model town     None      None
# 9970            model town     None      None
# 9971                 other     None      None
# 9972       pia road pgechs     None      None
# 9973       pia road pgechs     None      None
# 9974          raiwind road     None      None
# 9975          raiwind road     None      None
# 9976           bahria town     None      None
# 9977           bahria town     None      None
# 9978              chaklala     None      None
# 9979              chaklala     None      None
# 9980              chaklala     None      None
# 9981                chakri     None      None
# 9982                   dha     None      None
# 9983                   dha     None      None
# 9984                   dha     None      None
# 9985                   dha     None      None
# 9986                   dha     None      None
# 9987                   dha     None      None
# 9988                   dha     None      None
# 9989                   dha     None      None
# 9990           dhoke ratta     None      None
# 9991           ghauri town     None      None
# 9992           ghauri town     None      None
# 9993                 other     None      None
# 9994                 other     None      None
# 9995                 other     None      None
# 9996                 other     None      None
# 9997                 other     None      None
# 9998                 other     None      None
# 9999                 other     None      None

# %%
df_3 = df.copy()

# drop all rows where the value of the column 'Address Status' is 'complete'
df_3 = df_3[df_3['Address Status'] != 'complete']

df_3['Address Status'].value_counts()
# Out:
# incomplete    1453
# incorrect      115
# Name: Address Status, dtype: int64

# %%
# drop first 1000 incomplete addresses from the dataset
df_3 = df_3.iloc[1000:]

df_3['Address Status'].value_counts()
# Out:
# incomplete    453
# incorrect     115
# Name: Address Status, dtype: int64

# %%
from geopy.geocoders import GoogleV3
import time

API_KEY = 'AIzaSyBPbS3KQL93_EX8XHfiPcmc_aTur67xdzE'

def rate_limited_geocode(address, geolocator):
    location = geolocator.geocode(address)
    return location

df_3['latitude'] = None  # Add a new column to store latitude
df_3['longitude'] = None  # Add a new column to store longitude

geolocator = GoogleV3(api_key=API_KEY)

count = 0

for index, row in df_3.iterrows():

    count += 1

    address = f"{row['address']}, {row['area']}, {row['Area Category']}, {row['City']}"
    location = rate_limited_geocode(address, geolocator)
    if location is not None:
        df_3.at[index, 'latitude'] = location.latitude
        df_3.at[index, 'longitude'] = location.longitude

    if count % 50 == 0:
        # print last 50 rows
        print(df_3.iloc[count - 50: count])

# %%
df_3.head(20)
# Out:
#                                                 address  \
# 9432
# 9433
# 9434   botanical garden  jamia masjid gulzar east ma...
# 9435
# 9436             opposite side  madical housing scheme
# 9437                            allah ho chock street 4
# 9438                                ch chock pia road
# 9439  shadiwal chowk landmark beacone house school s...
# 9440                baba baker and sweet opp euro store
# 9441   university central of  back side pear mansoor...
# 9442                                              umt
# 9443                                      samsani khui
# 9444                            mian plaza model bazar
# 9445  naveed general store haider street allah hoo c...
# 9446                                     umt university
# 9447      umt - university of management and technology
# 9448                    ajudiya pur beer paind  b 1 b 2
# 9449        maryam girls hostel gulshan mustafa society
# 9450                             wafaqi colony lane 22
# 9451                     alkhan restaurant raiwind road
#
#                                         area Address Status    City  \
# 9432                         sozo water park     incomplete  lahore
# 9433                         sozo water park     incomplete  lahore
# 9434                              jallo pind     incomplete  lahore
# 9435               al raheem gardens phase 4     incomplete  lahore
# 9436  lahore medical housing society phase 1     incomplete  lahore
# 9437                                 block a     incomplete  lahore
# 9438                               block c 1     incomplete  lahore
# 9439                               block a 1     incomplete  lahore
# 9440                               block g 1     incomplete  lahore
# 9441                                 block p     incomplete  lahore
# 9442                               block c 2     incomplete  lahore
# 9443                                 block m     incomplete  lahore
# 9444                                 block d     incomplete  lahore
# 9445                                 block e     incomplete  lahore
# 9446                               block c 1     incomplete  lahore
# 9447                               block c 2     incomplete  lahore
# 9448                               block b 1     incomplete  lahore
# 9449                                 block c     incomplete  lahore
# 9450                               block f 2     incomplete  lahore
# 9451                                 phase 2     incomplete  lahore
#
#         Area Category   latitude  longitude
# 9432            jallo  31.582852  74.487224
# 9433            jallo  31.582852  74.487224
# 9434            jallo   31.52037  74.358747
# 9435            jallo  31.594403  74.474781
# 9436            jallo  31.570826  74.419104
# 9437       johar town  31.469706   74.29928
# 9438       johar town  31.449785  74.284246
# 9439       johar town  31.464088  74.303755
# 9440       johar town  31.477668  74.278819
# 9441       johar town   31.46387  74.269699
# 9442       johar town  31.451725   74.29367
# 9443       johar town  31.467557  74.275885
# 9444       johar town  31.475785  74.279977
# 9445       johar town  31.469706   74.29928
# 9446       johar town  31.454267  74.292021
# 9447       johar town  31.451725   74.29367
# 9448       johar town  31.451503  74.285237
# 9449       johar town  31.469092  74.300457
# 9450       johar town  31.455611  74.276105
# 9451  judicial colony  31.402863  74.229577

# %%
df_3.tail(20)
# Out:
#                                                 address           area  \
# 9980                                      makhi masjid        scheme 1
# 9981                                  paf base nur khan      22 chungi
# 9982                                babu mohala saddiq         phase 1
# 9983  house 654 street 06 model town humak sharqi is...        phase 1
# 9984      rcci industrial estate plot 44 street south 1        phase 5
# 9985  room 60 nab course sawan hostel block 5 a poli...        phase 1
# 9986                milan paint shop 40 al hajj market         phase 2
# 9987                             giga mall ground floor        phase 5
# 9988                                                           phase 2
# 9989                                    babia banglows         phase 1
# 9990                             giga mall ground floor    dhoke ratta
# 9991  airport housing society sactor 4 street 13 blo...        phase 4
# 9992             home 137 street 9 mangral model town          phase 1
# 9993                   ali medical f 8 markuz islamabad    peshawar rd
# 9994                   ali medical f 8 markuz islamabad    peshawar rd
# 9995  d 11 ground floor taj mehal market city saddar...     gawalmandi
# 9996                           watch co u-51 rajabazar            bani
# 9997  quaid-east-azam colony lane 3 street 6 almaka ...  dhamiyal camp
# 9998  main pwd double road shinka plazafirst floor o...     khanna pul
# 9999  2 nd floor cargo sale office pia booking offic...          sadar
#
#      Address Status        City Area Category   latitude  longitude
# 9980      incorrect  rawalpindi      chaklala  33.723888  73.084361
# 9981      incorrect  rawalpindi        chakri   33.61651  73.095136
# 9982      incorrect  rawalpindi           dha  33.565111  73.016914
# 9983      incorrect  rawalpindi           dha  33.538653  73.148237
# 9984      incorrect  rawalpindi           dha  31.462539  74.408593
# 9985      incorrect  rawalpindi           dha  33.544072  73.196911
# 9986      incorrect  rawalpindi           dha  33.559417  73.121683
# 9987      incorrect  rawalpindi           dha  33.528894   73.20874
# 9988      incorrect  rawalpindi           dha  33.559417  73.121683
# 9989      incorrect  rawalpindi           dha  33.565111  73.016914
# 9990      incorrect  rawalpindi   dhoke ratta  33.613884  73.044955
# 9991      incorrect  rawalpindi   ghauri town  33.614694  73.130862
# 9992      incorrect  rawalpindi   ghauri town  33.620533  73.140861
# 9993      incorrect  rawalpindi         other  33.710413  73.042016
# 9994      incorrect  rawalpindi         other  33.710413  73.042016
# 9995      incorrect  rawalpindi         other  33.614211  73.055067
# 9996      incorrect  rawalpindi         other  33.565111  73.016914
# 9997      incorrect  rawalpindi         other  33.534155  73.028721
# 9998      incorrect  rawalpindi         other  33.572655  73.147421
# 9999      incorrect  rawalpindi         other  33.596203  73.047815

# %%
df_3['latitude'].isnull().sum()
# Out:
# 0
